# %% [markdown]
# ### 1. Acquiring Data

# %%
import unicodecsv as csv

# %%
########### LONG WAY ###########
enrollment_data = []
file = open('enrollments.csv', 'rb')
data = csv.DictReader(file)

for i in data:
#     print(i)
    enrollment_data.append(i)
    
file.close()

# %%
enrollment_data
# Out:
# [{'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2017-11-05',
#   'cancel_date': '2017-11-10',
#   'days_to_cancel': '5',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-27',
#   'cancel_date': '2018-01-27',
#   'days_to_cancel': '0',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-10',
#   'days_to_cancel': '0',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-01-27',
#   'days_to_cancel': '13',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-27',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '42',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-27',
#   'cancel_date': '2018-01-27',
#   'days_to_cancel': '0',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-27',
#   'cancel_date': '2018-01-27',
#   'days_to_cancel': '0',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '700',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '429',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '429',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '60',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '60',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '77',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '60',
#   'status': 'current',
#   'join_date': '2018-04-01',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1300',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '369',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '322',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-02-02',
#   'days_to_cancel': '84',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '322',
#   'status': 'canceled',
#   'join_date': '2018-02-12',
#   'cancel_date': '2018-02-12',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '322',
#   'status': 'canceled',
#   'join_date': '2018-02-12',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '26',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '322',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '336',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '553',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '584',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '584',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '55',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '584',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1006',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '458',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '142',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '458',
#   'status': 'canceled',
#   'join_date': '2018-04-04',
#   'cancel_date': '2018-04-06',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '458',
#   'status': 'current',
#   'join_date': '2018-04-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1058',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1058',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '55',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1058',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '206',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '45',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '45',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '315',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '604',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '204',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '408',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '408',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '408',
#   'status': 'canceled',
#   'join_date': '2018-04-01',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '16',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '51',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '51',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '323',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '158',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '568',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '130',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '130',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '130',
#   'status': 'canceled',
#   'join_date': '2018-04-01',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '77',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '550',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-02',
#   'days_to_cancel': '173',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '550',
#   'status': 'canceled',
#   'join_date': '2018-05-28',
#   'cancel_date': '2018-07-04',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '44',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '44',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1020',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '838',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '198',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '368',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '440',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-02-18',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '675',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '57',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-02-18',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '57',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1090',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-26',
#   'days_to_cancel': '15',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '541',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '219',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '756',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '756',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-15',
#   'days_to_cancel': '61',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1219',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-12',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '101',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-04-20',
#   'days_to_cancel': '159',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1021',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1108',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '800',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-14',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '800',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-05-11',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '702',
#   'status': 'canceled',
#   'join_date': '2017-11-13',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '702',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '60',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '702',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '55',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '702',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '871',
#   'status': 'canceled',
#   'join_date': '2017-11-13',
#   'cancel_date': '2017-11-13',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '38',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '215',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '744',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-12-21',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '217',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '217',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '115',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '217',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1221',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-21',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1211',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1211',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-15',
#   'days_to_cancel': '61',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1211',
#   'status': 'current',
#   'join_date': '2018-03-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1051',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1286',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-21',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '53',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-12-21',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '53',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '895',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '895',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '283',
#   'status': 'current',
#   'join_date': '2017-11-15',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '283',
#   'status': 'canceled',
#   'join_date': '2017-11-13',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '338',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '60',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '338',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '20',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '338',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-02-22',
#   'days_to_cancel': '19',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '338',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '579',
#   'status': 'current',
#   'join_date': '2017-11-15',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '903',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2017-11-21',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '627',
#   'status': 'current',
#   'join_date': '2017-11-16',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '253',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '253',
#   'status': 'current',
#   'join_date': '2018-01-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '861',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '178',
#   'status': 'canceled',
#   'join_date': '2017-11-17',
#   'cancel_date': '2018-05-09',
#   'days_to_cancel': '173',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '822',
#   'status': 'canceled',
#   'join_date': '2017-11-17',
#   'cancel_date': '2018-01-15',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '822',
#   'status': 'current',
#   'join_date': '2018-07-18',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '96',
#   'status': 'current',
#   'join_date': '2017-11-17',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '123',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '123',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '943',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '620',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1204',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-12-17',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '195',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '890',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '354',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '837',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '114',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '114',
#   'status': 'current',
#   'join_date': '2018-05-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '810',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-13',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '394',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '158',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1253',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1253',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-01-20',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '504',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '219',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '537',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '72',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '268',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-12-17',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '268',
#   'status': 'canceled',
#   'join_date': '2018-04-03',
#   'cancel_date': '2018-08-10',
#   'days_to_cancel': '129',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '339',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '339',
#   'status': 'canceled',
#   'join_date': '2018-04-01',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '77',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '339',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1244',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1244',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1244',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '55',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1244',
#   'status': 'canceled',
#   'join_date': '2018-03-17',
#   'cancel_date': '2018-04-27',
#   'days_to_cancel': '41',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1244',
#   'status': 'canceled',
#   'join_date': '2018-05-17',
#   'cancel_date': '2018-08-17',
#   'days_to_cancel': '92',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '752',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '9',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '194',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '520',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-17',
#   'days_to_cancel': '127',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '102',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '367',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-04-02',
#   'days_to_cancel': '142',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '258',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-07-17',
#   'days_to_cancel': '249',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '522',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1047',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '329',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '329',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '29',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '329',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '329',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '20',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '329',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '35',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '225',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '612',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '612',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-03-17',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '150',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '179',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-17',
#   'days_to_cancel': '127',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '595',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '587',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '587',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '93',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '587',
#   'status': 'current',
#   'join_date': '2018-05-28',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '439',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '439',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '428',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '18',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-02-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '544',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '10',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '913',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '913',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-02-17',
#   'days_to_cancel': '34',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '23',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '576',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-02-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '431',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-17',
#   'days_to_cancel': '127',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '223',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '480',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '480',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '480',
#   'status': 'current',
#   'join_date': '2018-04-01',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '525',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-07-17',
#   'days_to_cancel': '249',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1111',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '119',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1111',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1111',
#   'status': 'canceled',
#   'join_date': '2018-04-01',
#   'cancel_date': '2018-04-18',
#   'days_to_cancel': '17',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1107',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '8',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '577',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-01-19',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '577',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-07-12',
#   'days_to_cancel': '157',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '92',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-07-19',
#   'days_to_cancel': '249',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '335',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-05-19',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '275',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '275',
#   'status': 'current',
#   'join_date': '2017-11-16',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '930',
#   'status': 'canceled',
#   'join_date': '2017-11-13',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '245',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '135',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '37',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '740',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '740',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-13',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '186',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '389',
#   'status': 'current',
#   'join_date': '2017-11-15',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '389',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1218',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '693',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '60',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '693',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-01-23',
#   'days_to_cancel': '9',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '770',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '88',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '115',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '88',
#   'status': 'current',
#   'join_date': '2018-04-01',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '88',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '845',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2017-11-23',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '983',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '983',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-01-23',
#   'days_to_cancel': '9',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1118',
#   'status': 'canceled',
#   'join_date': '2017-11-17',
#   'cancel_date': '2017-12-24',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1118',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '499',
#   'status': 'canceled',
#   'join_date': '2017-11-17',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '499',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-05-13',
#   'days_to_cancel': '96',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '590',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '62',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '590',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '590',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '35',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '264',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '62',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '264',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-02-25',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '300',
#   'status': 'current',
#   'join_date': '2017-12-03',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '54',
#   'status': 'current',
#   'join_date': '2017-12-03',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1043',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2017-12-04',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1130',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2018-01-25',
#   'days_to_cancel': '53',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '654',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2017-12-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '654',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2017-12-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '654',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2017-12-03',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '736',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2018-03-11',
#   'days_to_cancel': '97',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '964',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2017-12-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '976',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2018-01-11',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1203',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2017-12-09',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '278',
#   'status': 'current',
#   'join_date': '2017-12-04',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '377',
#   'status': 'current',
#   'join_date': '2017-12-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '342',
#   'status': 'current',
#   'join_date': '2017-12-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '358',
#   'status': 'current',
#   'join_date': '2017-12-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '316',
#   'status': 'canceled',
#   'join_date': '2017-12-06',
#   'cancel_date': '2018-06-13',
#   'days_to_cancel': '189',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '347',
#   'status': 'canceled',
#   'join_date': '2017-12-07',
#   'cancel_date': '2018-03-14',
#   'days_to_cancel': '97',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '347',
#   'status': 'current',
#   'join_date': '2018-04-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '295',
#   'status': 'canceled',
#   'join_date': '2017-12-07',
#   'cancel_date': '2017-12-07',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '295',
#   'status': 'current',
#   'join_date': '2018-04-03',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '343',
#   'status': 'canceled',
#   'join_date': '2017-12-07',
#   'cancel_date': '2018-03-14',
#   'days_to_cancel': '97',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1127',
#   'status': 'canceled',
#   'join_date': '2017-12-07',
#   'cancel_date': '2017-12-08',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1076',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2017-12-12',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '502',
#   'status': 'current',
#   'join_date': '2017-12-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '502',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2017-11-21',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1223',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2017-12-13',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '221',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2018-02-10',
#   'days_to_cancel': '69',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '631',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2017-12-08',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '631',
#   'status': 'canceled',
#   'join_date': '2018-05-08',
#   'cancel_date': '2018-07-15',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '495',
#   'status': 'current',
#   'join_date': '2017-12-04',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '495',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1009',
#   'status': 'canceled',
#   'join_date': '2017-12-05',
#   'cancel_date': '2018-02-12',
#   'days_to_cancel': '69',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '364',
#   'status': 'current',
#   'join_date': '2017-12-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1252',
#   'status': 'canceled',
#   'join_date': '2017-12-05',
#   'cancel_date': '2017-12-11',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '909',
#   'status': 'canceled',
#   'join_date': '2017-12-05',
#   'cancel_date': '2017-12-28',
#   'days_to_cancel': '23',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1156',
#   'status': 'canceled',
#   'join_date': '2017-12-06',
#   'cancel_date': '2017-12-08',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '524',
#   'status': 'canceled',
#   'join_date': '2017-12-06',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '524',
#   'status': 'current',
#   'join_date': '2018-03-04',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '560',
#   'status': 'current',
#   'join_date': '2017-12-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '570',
#   'status': 'current',
#   'join_date': '2017-12-07',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '581',
#   'status': 'current',
#   'join_date': '2017-12-07',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '759',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '57',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '759',
#   'status': 'canceled',
#   'join_date': '2018-04-08',
#   'cancel_date': '2018-04-15',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '759',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '64',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '896',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '57',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '896',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '29',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '896',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '35',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '896',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '346',
#   'status': 'current',
#   'join_date': '2017-12-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '346',
#   'status': 'canceled',
#   'join_date': '2017-12-05',
#   'cancel_date': '2017-12-05',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '411',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '57',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
# ...
#   'cancel_date': '2018-02-18',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '746',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-03-12',
#   'days_to_cancel': '35',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '279',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '62',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '279',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '136',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '62',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '136',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1092',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-02-09',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '799',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-02-06',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1042',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-02-28',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1042',
#   'status': 'canceled',
#   'join_date': '2018-05-28',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '789',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-02-06',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '413',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-05-13',
#   'days_to_cancel': '96',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '738',
#   'status': 'canceled',
#   'join_date': '2018-02-07',
#   'cancel_date': '2018-02-13',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '306',
#   'status': 'canceled',
#   'join_date': '2018-02-08',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '306',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '436',
#   'status': 'current',
#   'join_date': '2018-02-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '35',
#   'status': 'current',
#   'join_date': '2018-02-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '463',
#   'status': 'current',
#   'join_date': '2018-02-09',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1105',
#   'status': 'canceled',
#   'join_date': '2018-02-09',
#   'cancel_date': '2018-02-13',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '284',
#   'status': 'canceled',
#   'join_date': '2018-02-09',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '58',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '284',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '521',
#   'status': 'canceled',
#   'join_date': '2018-02-09',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '58',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '521',
#   'status': 'canceled',
#   'join_date': '2018-04-08',
#   'cancel_date': '2018-07-16',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1229',
#   'status': 'canceled',
#   'join_date': '2018-02-09',
#   'cancel_date': '2018-02-12',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1049',
#   'status': 'canceled',
#   'join_date': '2018-02-10',
#   'cancel_date': '2018-03-04',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1198',
#   'status': 'canceled',
#   'join_date': '2018-02-11',
#   'cancel_date': '2018-02-15',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1198',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-04-11',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '720',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-04-11',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '239',
#   'status': 'current',
#   'join_date': '2018-03-04',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '819',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-03-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '819',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-03-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '958',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-06-07',
#   'days_to_cancel': '95',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '718',
#   'status': 'canceled',
#   'join_date': '2018-05-08',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '42',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '475',
#   'status': 'current',
#   'join_date': '2018-05-09',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '276',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '608',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '293',
#   'status': 'canceled',
#   'join_date': '2018-05-10',
#   'cancel_date': '2018-08-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '341',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '501',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '858',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-07-19',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '713',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-07-04',
#   'days_to_cancel': '53',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1040',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1040',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1305',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1091',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-05-18',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1192',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '25',
#   'status': 'current',
#   'join_date': '2018-05-12',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '25',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-02-18',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '674',
#   'status': 'current',
#   'join_date': '2018-05-12',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '734',
#   'status': 'canceled',
#   'join_date': '2018-05-13',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '988',
#   'status': 'canceled',
#   'join_date': '2018-05-13',
#   'cancel_date': '2018-07-20',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '771',
#   'status': 'current',
#   'join_date': '2018-05-13',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '771',
#   'status': 'canceled',
#   'join_date': '2017-12-09',
#   'cancel_date': '2017-12-15',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1016',
#   'status': 'canceled',
#   'join_date': '2018-05-13',
#   'cancel_date': '2018-05-19',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '877',
#   'status': 'canceled',
#   'join_date': '2018-05-13',
#   'cancel_date': '2018-06-04',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '63',
#   'status': 'current',
#   'join_date': '2018-05-28',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '481',
#   'status': 'current',
#   'join_date': '2018-05-28',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '902',
#   'status': 'canceled',
#   'join_date': '2018-05-29',
#   'cancel_date': '2018-05-29',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '996',
#   'status': 'canceled',
#   'join_date': '2018-05-29',
#   'cancel_date': '2018-05-29',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '42',
#   'status': 'current',
#   'join_date': '2018-05-30',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '42',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-05-11',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '939',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '11',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '262',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '167',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '302',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '551',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '609',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '109',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '211',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '274',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '704',
#   'status': 'canceled',
#   'join_date': '2018-05-06',
#   'cancel_date': '2018-07-13',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '407',
#   'status': 'canceled',
#   'join_date': '2018-05-06',
#   'cancel_date': '2018-08-13',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '360',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '540',
#   'status': 'current',
#   'join_date': '2018-05-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1173',
#   'status': 'current',
#   'join_date': '2018-05-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '886',
#   'status': 'canceled',
#   'join_date': '2018-05-08',
#   'cancel_date': '2018-05-13',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '112',
#   'status': 'current',
#   'join_date': '2018-05-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '479',
#   'status': 'current',
#   'join_date': '2018-05-09',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1275',
#   'status': 'canceled',
#   'join_date': '2018-05-09',
#   'cancel_date': '2018-05-11',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '237',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '487',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '304',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '330',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1250',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '27',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1064',
#   'status': 'canceled',
#   'join_date': '2018-05-11',
#   'cancel_date': '2018-05-12',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '714',
#   'status': 'canceled',
#   'join_date': '2018-05-11',
#   'cancel_date': '2018-05-14',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '714',
#   'status': 'canceled',
#   'join_date': '2018-07-09',
#   'cancel_date': '2018-07-12',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  ...]

# %%
########### SHORTER WAY ###########
with open('enrollments.csv', 'rb') as file:
    data = csv.DictReader(file)
    enrollment_data = list(data)
    
enrollment_data
# Out:
# [{'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2017-11-05',
#   'cancel_date': '2017-11-10',
#   'days_to_cancel': '5',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-27',
#   'cancel_date': '2018-01-27',
#   'days_to_cancel': '0',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-10',
#   'days_to_cancel': '0',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-01-27',
#   'days_to_cancel': '13',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-27',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '42',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-27',
#   'cancel_date': '2018-01-27',
#   'days_to_cancel': '0',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '448',
#   'status': 'canceled',
#   'join_date': '2018-01-27',
#   'cancel_date': '2018-01-27',
#   'days_to_cancel': '0',
#   'is_enrolled': 'TRUE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '700',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '429',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '429',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '60',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '60',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '77',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '60',
#   'status': 'current',
#   'join_date': '2018-04-01',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1300',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '369',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '322',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-02-02',
#   'days_to_cancel': '84',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '322',
#   'status': 'canceled',
#   'join_date': '2018-02-12',
#   'cancel_date': '2018-02-12',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '322',
#   'status': 'canceled',
#   'join_date': '2018-02-12',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '26',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '322',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '336',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '553',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '584',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '584',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '55',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '584',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1006',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '458',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '142',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '458',
#   'status': 'canceled',
#   'join_date': '2018-04-04',
#   'cancel_date': '2018-04-06',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '458',
#   'status': 'current',
#   'join_date': '2018-04-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1058',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1058',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '55',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1058',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '206',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '45',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '45',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '315',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '604',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '204',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '408',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '408',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '408',
#   'status': 'canceled',
#   'join_date': '2018-04-01',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '16',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '51',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '51',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '323',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '158',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '568',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '130',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '130',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '130',
#   'status': 'canceled',
#   'join_date': '2018-04-01',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '77',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '550',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-02',
#   'days_to_cancel': '173',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '550',
#   'status': 'canceled',
#   'join_date': '2018-05-28',
#   'cancel_date': '2018-07-04',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '44',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '44',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1020',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '838',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '198',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '368',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '440',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-02-18',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '675',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '57',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-02-18',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '57',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1090',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-26',
#   'days_to_cancel': '15',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '541',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '219',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '756',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '756',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-15',
#   'days_to_cancel': '61',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1219',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-12',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '101',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-04-20',
#   'days_to_cancel': '159',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1021',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1108',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '800',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-14',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '800',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-05-11',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '702',
#   'status': 'canceled',
#   'join_date': '2017-11-13',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '702',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '60',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '702',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '55',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '702',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '871',
#   'status': 'canceled',
#   'join_date': '2017-11-13',
#   'cancel_date': '2017-11-13',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '38',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '215',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '744',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-12-21',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '217',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '217',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '115',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '217',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1221',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-21',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1211',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1211',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-15',
#   'days_to_cancel': '61',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1211',
#   'status': 'current',
#   'join_date': '2018-03-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1051',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1286',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-21',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '53',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-12-21',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '53',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '895',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '895',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '283',
#   'status': 'current',
#   'join_date': '2017-11-15',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '283',
#   'status': 'canceled',
#   'join_date': '2017-11-13',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '338',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '60',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '338',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '20',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '338',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-02-22',
#   'days_to_cancel': '19',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '338',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '579',
#   'status': 'current',
#   'join_date': '2017-11-15',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '903',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2017-11-21',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '627',
#   'status': 'current',
#   'join_date': '2017-11-16',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '253',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '253',
#   'status': 'current',
#   'join_date': '2018-01-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '861',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '178',
#   'status': 'canceled',
#   'join_date': '2017-11-17',
#   'cancel_date': '2018-05-09',
#   'days_to_cancel': '173',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '822',
#   'status': 'canceled',
#   'join_date': '2017-11-17',
#   'cancel_date': '2018-01-15',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '822',
#   'status': 'current',
#   'join_date': '2018-07-18',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '96',
#   'status': 'current',
#   'join_date': '2017-11-17',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '123',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '123',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '943',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '620',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1204',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-12-17',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '195',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '890',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '354',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '837',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '114',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '114',
#   'status': 'current',
#   'join_date': '2018-05-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '810',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-13',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '394',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '158',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1253',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1253',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-01-20',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '504',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '219',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '537',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '72',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '268',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-12-17',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '268',
#   'status': 'canceled',
#   'join_date': '2018-04-03',
#   'cancel_date': '2018-08-10',
#   'days_to_cancel': '129',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '339',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '339',
#   'status': 'canceled',
#   'join_date': '2018-04-01',
#   'cancel_date': '2018-06-17',
#   'days_to_cancel': '77',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '339',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1244',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1244',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1244',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '55',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1244',
#   'status': 'canceled',
#   'join_date': '2018-03-17',
#   'cancel_date': '2018-04-27',
#   'days_to_cancel': '41',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1244',
#   'status': 'canceled',
#   'join_date': '2018-05-17',
#   'cancel_date': '2018-08-17',
#   'days_to_cancel': '92',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '752',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '9',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '194',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '520',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-17',
#   'days_to_cancel': '127',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '102',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '367',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-04-02',
#   'days_to_cancel': '142',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '258',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-07-17',
#   'days_to_cancel': '249',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '522',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1047',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2017-11-11',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '329',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '329',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '29',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '329',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '329',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '20',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '329',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '35',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '225',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '612',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '612',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-03-17',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '150',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '179',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-17',
#   'days_to_cancel': '127',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '595',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '587',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '587',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-04-17',
#   'days_to_cancel': '93',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '587',
#   'status': 'current',
#   'join_date': '2018-05-28',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '439',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '439',
#   'status': 'current',
#   'join_date': '2018-03-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '428',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '18',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-02-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '544',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '10',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '913',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '65',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '913',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-02-17',
#   'days_to_cancel': '34',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '23',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '576',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-02-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '431',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-17',
#   'days_to_cancel': '127',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '223',
#   'status': 'current',
#   'join_date': '2017-11-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '480',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '120',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '480',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '480',
#   'status': 'current',
#   'join_date': '2018-04-01',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '525',
#   'status': 'canceled',
#   'join_date': '2017-11-10',
#   'cancel_date': '2018-07-17',
#   'days_to_cancel': '249',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1111',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '119',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1111',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1111',
#   'status': 'canceled',
#   'join_date': '2018-04-01',
#   'cancel_date': '2018-04-18',
#   'days_to_cancel': '17',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1107',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '8',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '577',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-01-19',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '577',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-07-12',
#   'days_to_cancel': '157',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '92',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-07-19',
#   'days_to_cancel': '249',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '335',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2018-05-19',
#   'days_to_cancel': '188',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '275',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-16',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '275',
#   'status': 'current',
#   'join_date': '2017-11-16',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '930',
#   'status': 'canceled',
#   'join_date': '2017-11-13',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '245',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '135',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '37',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '740',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '740',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-13',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '186',
#   'status': 'current',
#   'join_date': '2017-11-14',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '389',
#   'status': 'current',
#   'join_date': '2017-11-15',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '389',
#   'status': 'canceled',
#   'join_date': '2017-11-14',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1218',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2017-11-15',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '693',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '60',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '693',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-01-23',
#   'days_to_cancel': '9',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '770',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2017-11-19',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '88',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '115',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '88',
#   'status': 'current',
#   'join_date': '2018-04-01',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '88',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-01',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '845',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2017-11-23',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '983',
#   'status': 'canceled',
#   'join_date': '2017-11-16',
#   'cancel_date': '2018-01-14',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '983',
#   'status': 'canceled',
#   'join_date': '2018-01-14',
#   'cancel_date': '2018-01-23',
#   'days_to_cancel': '9',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1118',
#   'status': 'canceled',
#   'join_date': '2017-11-17',
#   'cancel_date': '2017-12-24',
#   'days_to_cancel': '37',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1118',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '499',
#   'status': 'canceled',
#   'join_date': '2017-11-17',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '499',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-05-13',
#   'days_to_cancel': '96',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '590',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '62',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '590',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '590',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '35',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '264',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '62',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '264',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-02-25',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '300',
#   'status': 'current',
#   'join_date': '2017-12-03',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '54',
#   'status': 'current',
#   'join_date': '2017-12-03',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1043',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2017-12-04',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1130',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2018-01-25',
#   'days_to_cancel': '53',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '654',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2017-12-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '654',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2017-12-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '654',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2017-12-03',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '736',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2018-03-11',
#   'days_to_cancel': '97',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '964',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2017-12-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '976',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2018-01-11',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1203',
#   'status': 'canceled',
#   'join_date': '2017-12-04',
#   'cancel_date': '2017-12-09',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '278',
#   'status': 'current',
#   'join_date': '2017-12-04',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '377',
#   'status': 'current',
#   'join_date': '2017-12-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '342',
#   'status': 'current',
#   'join_date': '2017-12-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '358',
#   'status': 'current',
#   'join_date': '2017-12-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '316',
#   'status': 'canceled',
#   'join_date': '2017-12-06',
#   'cancel_date': '2018-06-13',
#   'days_to_cancel': '189',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '347',
#   'status': 'canceled',
#   'join_date': '2017-12-07',
#   'cancel_date': '2018-03-14',
#   'days_to_cancel': '97',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '347',
#   'status': 'current',
#   'join_date': '2018-04-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '295',
#   'status': 'canceled',
#   'join_date': '2017-12-07',
#   'cancel_date': '2017-12-07',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '295',
#   'status': 'current',
#   'join_date': '2018-04-03',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '343',
#   'status': 'canceled',
#   'join_date': '2017-12-07',
#   'cancel_date': '2018-03-14',
#   'days_to_cancel': '97',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1127',
#   'status': 'canceled',
#   'join_date': '2017-12-07',
#   'cancel_date': '2017-12-08',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1076',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2017-12-12',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '502',
#   'status': 'current',
#   'join_date': '2017-12-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '502',
#   'status': 'canceled',
#   'join_date': '2017-11-15',
#   'cancel_date': '2017-11-21',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1223',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2017-12-13',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '221',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2018-02-10',
#   'days_to_cancel': '69',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '631',
#   'status': 'canceled',
#   'join_date': '2017-12-03',
#   'cancel_date': '2017-12-08',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '631',
#   'status': 'canceled',
#   'join_date': '2018-05-08',
#   'cancel_date': '2018-07-15',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '495',
#   'status': 'current',
#   'join_date': '2017-12-04',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '495',
#   'status': 'canceled',
#   'join_date': '2017-11-12',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1009',
#   'status': 'canceled',
#   'join_date': '2017-12-05',
#   'cancel_date': '2018-02-12',
#   'days_to_cancel': '69',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '364',
#   'status': 'current',
#   'join_date': '2017-12-05',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1252',
#   'status': 'canceled',
#   'join_date': '2017-12-05',
#   'cancel_date': '2017-12-11',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '909',
#   'status': 'canceled',
#   'join_date': '2017-12-05',
#   'cancel_date': '2017-12-28',
#   'days_to_cancel': '23',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1156',
#   'status': 'canceled',
#   'join_date': '2017-12-06',
#   'cancel_date': '2017-12-08',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '524',
#   'status': 'canceled',
#   'join_date': '2017-12-06',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '524',
#   'status': 'current',
#   'join_date': '2018-03-04',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '560',
#   'status': 'current',
#   'join_date': '2017-12-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '570',
#   'status': 'current',
#   'join_date': '2017-12-07',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '581',
#   'status': 'current',
#   'join_date': '2017-12-07',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '759',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '57',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '759',
#   'status': 'canceled',
#   'join_date': '2018-04-08',
#   'cancel_date': '2018-04-15',
#   'days_to_cancel': '7',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '759',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '64',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '896',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '57',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '896',
#   'status': 'canceled',
#   'join_date': '2018-03-10',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '29',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '896',
#   'status': 'canceled',
#   'join_date': '2018-02-03',
#   'cancel_date': '2018-03-10',
#   'days_to_cancel': '35',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '896',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '346',
#   'status': 'current',
#   'join_date': '2017-12-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '346',
#   'status': 'canceled',
#   'join_date': '2017-12-05',
#   'cancel_date': '2017-12-05',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '411',
#   'status': 'canceled',
#   'join_date': '2017-12-08',
#   'cancel_date': '2018-02-03',
#   'days_to_cancel': '57',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
# ...
#   'cancel_date': '2018-02-18',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '746',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-03-12',
#   'days_to_cancel': '35',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '279',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '62',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '279',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '136',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '62',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '136',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1092',
#   'status': 'canceled',
#   'join_date': '2018-02-05',
#   'cancel_date': '2018-02-09',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '799',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-02-06',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1042',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-02-28',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1042',
#   'status': 'canceled',
#   'join_date': '2018-05-28',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '789',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-02-06',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '413',
#   'status': 'canceled',
#   'join_date': '2018-02-06',
#   'cancel_date': '2018-05-13',
#   'days_to_cancel': '96',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '738',
#   'status': 'canceled',
#   'join_date': '2018-02-07',
#   'cancel_date': '2018-02-13',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '306',
#   'status': 'canceled',
#   'join_date': '2018-02-08',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '59',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '306',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '436',
#   'status': 'current',
#   'join_date': '2018-02-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '35',
#   'status': 'current',
#   'join_date': '2018-02-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '463',
#   'status': 'current',
#   'join_date': '2018-02-09',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1105',
#   'status': 'canceled',
#   'join_date': '2018-02-09',
#   'cancel_date': '2018-02-13',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '284',
#   'status': 'canceled',
#   'join_date': '2018-02-09',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '58',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '284',
#   'status': 'current',
#   'join_date': '2018-04-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '521',
#   'status': 'canceled',
#   'join_date': '2018-02-09',
#   'cancel_date': '2018-04-08',
#   'days_to_cancel': '58',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '521',
#   'status': 'canceled',
#   'join_date': '2018-04-08',
#   'cancel_date': '2018-07-16',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1229',
#   'status': 'canceled',
#   'join_date': '2018-02-09',
#   'cancel_date': '2018-02-12',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1049',
#   'status': 'canceled',
#   'join_date': '2018-02-10',
#   'cancel_date': '2018-03-04',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1198',
#   'status': 'canceled',
#   'join_date': '2018-02-11',
#   'cancel_date': '2018-02-15',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1198',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-04-11',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '720',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-04-11',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '239',
#   'status': 'current',
#   'join_date': '2018-03-04',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '819',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-03-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '819',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-03-04',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '958',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-06-07',
#   'days_to_cancel': '95',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '718',
#   'status': 'canceled',
#   'join_date': '2018-05-08',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '42',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '475',
#   'status': 'current',
#   'join_date': '2018-05-09',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '276',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '608',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '293',
#   'status': 'canceled',
#   'join_date': '2018-05-10',
#   'cancel_date': '2018-08-17',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '341',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '501',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '858',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-07-19',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '713',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-07-04',
#   'days_to_cancel': '53',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1040',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1040',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2017-11-17',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1305',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-06-19',
#   'days_to_cancel': '38',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1091',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-05-18',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1192',
#   'status': 'canceled',
#   'join_date': '2018-05-12',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '25',
#   'status': 'current',
#   'join_date': '2018-05-12',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '25',
#   'status': 'canceled',
#   'join_date': '2017-11-11',
#   'cancel_date': '2018-02-18',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '674',
#   'status': 'current',
#   'join_date': '2018-05-12',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '734',
#   'status': 'canceled',
#   'join_date': '2018-05-13',
#   'cancel_date': '2018-05-17',
#   'days_to_cancel': '4',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '988',
#   'status': 'canceled',
#   'join_date': '2018-05-13',
#   'cancel_date': '2018-07-20',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '771',
#   'status': 'current',
#   'join_date': '2018-05-13',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '771',
#   'status': 'canceled',
#   'join_date': '2017-12-09',
#   'cancel_date': '2017-12-15',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '1016',
#   'status': 'canceled',
#   'join_date': '2018-05-13',
#   'cancel_date': '2018-05-19',
#   'days_to_cancel': '6',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '877',
#   'status': 'canceled',
#   'join_date': '2018-05-13',
#   'cancel_date': '2018-06-04',
#   'days_to_cancel': '22',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '63',
#   'status': 'current',
#   'join_date': '2018-05-28',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '481',
#   'status': 'current',
#   'join_date': '2018-05-28',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '902',
#   'status': 'canceled',
#   'join_date': '2018-05-29',
#   'cancel_date': '2018-05-29',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '996',
#   'status': 'canceled',
#   'join_date': '2018-05-29',
#   'cancel_date': '2018-05-29',
#   'days_to_cancel': '0',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '42',
#   'status': 'current',
#   'join_date': '2018-05-30',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '42',
#   'status': 'canceled',
#   'join_date': '2018-03-04',
#   'cancel_date': '2018-05-11',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '939',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '11',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '262',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '167',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '302',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '551',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '609',
#   'status': 'current',
#   'join_date': '2018-04-24',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '109',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '211',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '274',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '704',
#   'status': 'canceled',
#   'join_date': '2018-05-06',
#   'cancel_date': '2018-07-13',
#   'days_to_cancel': '68',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '407',
#   'status': 'canceled',
#   'join_date': '2018-05-06',
#   'cancel_date': '2018-08-13',
#   'days_to_cancel': '99',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '360',
#   'status': 'current',
#   'join_date': '2018-05-06',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '540',
#   'status': 'current',
#   'join_date': '2018-05-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1173',
#   'status': 'current',
#   'join_date': '2018-05-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '886',
#   'status': 'canceled',
#   'join_date': '2018-05-08',
#   'cancel_date': '2018-05-13',
#   'days_to_cancel': '5',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '112',
#   'status': 'current',
#   'join_date': '2018-05-08',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '479',
#   'status': 'current',
#   'join_date': '2018-05-09',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1275',
#   'status': 'canceled',
#   'join_date': '2018-05-09',
#   'cancel_date': '2018-05-11',
#   'days_to_cancel': '2',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '237',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '487',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '304',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '330',
#   'status': 'current',
#   'join_date': '2018-05-10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1250',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '27',
#   'status': 'current',
#   'join_date': '2018-05-11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'FALSE'},
#  {'account_key': '1064',
#   'status': 'canceled',
#   'join_date': '2018-05-11',
#   'cancel_date': '2018-05-12',
#   'days_to_cancel': '1',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '714',
#   'status': 'canceled',
#   'join_date': '2018-05-11',
#   'cancel_date': '2018-05-14',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  {'account_key': '714',
#   'status': 'canceled',
#   'join_date': '2018-07-09',
#   'cancel_date': '2018-07-12',
#   'days_to_cancel': '3',
#   'is_enrolled': 'FALSE',
#   'is_canceled': 'TRUE'},
#  ...]

# %%
########### BEST WAY ###########
def read_from_csv(filename):
    with open(filename, 'rb') as file:
        data = csv.DictReader(file)
        return list(data)

# %%
enrollment_data = read_from_csv('enrollments.csv')
engagement_data = read_from_csv('engagements.csv')
submission_data = read_from_csv('submissions.csv')

# %%
enrollment_data[0]
# Out:
# {'account_key': '448',
#  'status': 'canceled',
#  'join_date': '2017-11-10',
#  'cancel_date': '2018-01-14',
#  'days_to_cancel': '65',
#  'is_enrolled': 'TRUE',
#  'is_canceled': 'TRUE'}

# %%
engagement_data[0]
# Out:
# {'acct': '0',
#  'utc_date': '2018-01-09',
#  'num_courses_visited': '1',
#  'total_minutes_visited': '11.6793745',
#  'lessons_completed': '0',
#  'projects_completed': '0'}

# %%
submission_data[0]
# Out:
# {'creation_date': '2018-01-14',
#  'completion_date': '2018-01-16',
#  'assigned_rating': 'UNGRADED',
#  'account_key': '256',
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %% [markdown]
# ### 2. Cleaning Data

# %% [markdown]
# ##### Fix data types

# %%
from datetime import datetime as dt

def convert_to_date(date_string):
    if date_string == '':
        return None
    return dt.strptime(date_string, '%Y-%m-%d') #'2020-11-16'

def convert_to_int(int_string):
    if int_string == '':
        return None
    return int(int_string)

def convert_to_float(float_string):
    if float_string == '':
        return None
    return float(float_string)

def convert_to_bool(bool_string):
    if bool_string == '':
        return None
    elif bool_string.upper() == 'TRUE':
        return True
    elif bool_string.upper() == 'FALSE':
        return False

# %%
for record in enrollment_data:
    record['join_date'] = convert_to_date(record['join_date'])
    record['cancel_date'] = convert_to_date(record['cancel_date'])
    record['days_to_cancel'] = convert_to_int(record['days_to_cancel'])
    record['is_enrolled'] = convert_to_bool(record['is_enrolled'])
    record['is_canceled'] = convert_to_bool(record['is_canceled'])

# %%
enrollment_data[0]
# Out:
# {'account_key': '448',
#  'status': 'canceled',
#  'join_date': datetime.datetime(2017, 11, 10, 0, 0),
#  'cancel_date': datetime.datetime(2018, 1, 14, 0, 0),
#  'days_to_cancel': 65,
#  'is_enrolled': True,
#  'is_canceled': True}

# %%
for record in engagement_data:
    record['utc_date'] =  convert_to_date(record['utc_date'])
    record['num_courses_visited'] = convert_to_int(record['num_courses_visited'])
    record['total_minutes_visited'] = convert_to_float(record['total_minutes_visited'])
    record['lessons_completed'] = convert_to_int(record['lessons_completed'])
    record['projects_completed'] = convert_to_int(record['projects_completed'])
    record['account_key'] = record['acct']
    del record['acct']

# %%
engagement_data[0]
# Out:
# {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#  'num_courses_visited': 1,
#  'total_minutes_visited': 11.6793745,
#  'lessons_completed': 0,
#  'projects_completed': 0,
#  'account_key': '0'}

# %%
for record in submission_data:
    record['creation_date'] = convert_to_date(record['creation_date'])
    record['completion_date'] = convert_to_date(record['completion_date'])

# %%
submission_data[0]
# Out:
# {'creation_date': datetime.datetime(2018, 1, 14, 0, 0),
#  'completion_date': datetime.datetime(2018, 1, 16, 0, 0),
#  'assigned_rating': 'UNGRADED',
#  'account_key': '256',
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %% [markdown]
# ### 3. Answering Questions w/ Data

# %%
print(f"Enrollment records: {len(enrollment_data)}")
print(f"Engagement records: {len(engagement_data)}")
print(f"Submission records: {len(submission_data)}")

# Find unique records
def get_unique_records(data, column_name):
    unique_data = set()
    for i in data:
        unique_data.add(i[column_name])
    return unique_data

unique_enrollment_data = get_unique_records(enrollment_data, 'account_key')
unique_engagement_data = get_unique_records(engagement_data, 'account_key')
unique_submission_data = get_unique_records(submission_data, 'account_key')

print("="*30)
print(f"Unique enrollment records: {len(unique_enrollment_data)}")
print(f"Unique engagement records: {len(unique_engagement_data)}")
print(f"Unique submission records: {len(unique_submission_data)}")
# Out:
# Enrollment records: 1640
# Engagement records: 136240
# Submission records: 3642
# ==============================
# Unique enrollment records: 1302
# Unique engagement records: 1237
# Unique submission records: 743

# %% [markdown]
# #### Find all quality accounts where:
# ##### 1. 'is_canceled' is False
# ##### 2. 'days_to_cancel' is greater than 7
# ##### 3. retrieve one record with most recent 'join_date', but have account keys that show up multiple times

# %%
quality_accounts = dict()

for i in enrollment_data:
    if i['days_to_cancel'] is not None:
        if not i['is_canceled'] or i['days_to_cancel'] > 7:
            if i['account_key'] not in quality_accounts or i['join_date'] > quality_accounts[i['account_key']]:
                quality_accounts[i['account_key']] = i['join_date']


len(quality_accounts)
# Out:
# 448

# %%
def remove_free_trials(data):
    paid_accounts = []
    for i in data:
        if i['account_key'] in quality_accounts:
            paid_accounts.append(i)
    return paid_accounts

quality_enrollments = remove_free_trials(enrollment_data)
quality_engagements = remove_free_trials(engagement_data)
quality_submissions = remove_free_trials(submission_data)

# %%
print(f"Quality Enrollments: {len(quality_enrollments)}")
print(f"Quality Engagements: {len(quality_engagements)}")
print(f"Quality Submissions: {len(quality_submissions)}")
# Out:
# Quality Enrollments: 734
# Quality Engagements: 56254
# Quality Submissions: 1118

# %%
def engagements_within_first_week(date_joined, date_of_first_engagement):
    time_diff = date_of_first_engagement - date_joined
    if time_diff.days >= 0 and time_diff.days < 7:
        return True
    return False

# %%
quality_engagements[0]
# Out:
# {'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#  'num_courses_visited': 2,
#  'total_minutes_visited': 136.1835995,
#  'lessons_completed': 0,
#  'projects_completed': 0,
#  'account_key': '3'}

# %%
first_week_engagements = []

for i in quality_engagements:
    if engagements_within_first_week(quality_accounts[i['account_key']], i['utc_date']):
        first_week_engagements.append(i)

# %%
first_week_engagements
# Out:
# [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 136.1835995,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 11.0550435,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 34.615231,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '3'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 406.333269167,
#   'lessons_completed': 3,
#   'projects_completed': 0,
#   'account_key': '3'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 91.475528,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 148.244103333,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '3'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3'},
#  {'utc_date': datetime.datetime(2018, 1, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 59.7267188333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5'},
#  {'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5'},
#  {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 103.568613833,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5'},
#  {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 80.1818903333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5'},
#  {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 36.2465346667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5'},
#  {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 50.034099,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5'},
#  {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5'},
#  {'utc_date': datetime.datetime(2018, 3, 4, 0, 0),
#   'num_courses_visited': 4,
#   'total_minutes_visited': 172.709897334,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '15'},
#  {'utc_date': datetime.datetime(2018, 3, 5, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 108.647330667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15'},
#  {'utc_date': datetime.datetime(2018, 3, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 128.439285667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15'},
#  {'utc_date': datetime.datetime(2018, 3, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15'},
#  {'utc_date': datetime.datetime(2018, 3, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15'},
#  {'utc_date': datetime.datetime(2018, 3, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 186.486383667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15'},
#  {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 387.092143,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15'},
#  {'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 87.1443163333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 33.370874,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 16.5147731667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 18.106194,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18'},
#  {'utc_date': datetime.datetime(2018, 4, 6, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19'},
#  {'utc_date': datetime.datetime(2018, 4, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19'},
#  {'utc_date': datetime.datetime(2018, 4, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19'},
#  {'utc_date': datetime.datetime(2018, 4, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19'},
#  {'utc_date': datetime.datetime(2018, 4, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19'},
#  {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19'},
#  {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19'},
#  {'utc_date': datetime.datetime(2017, 12, 3, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24'},
#  {'utc_date': datetime.datetime(2017, 12, 4, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24'},
#  {'utc_date': datetime.datetime(2017, 12, 5, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24'},
#  {'utc_date': datetime.datetime(2017, 12, 6, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24'},
#  {'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 217.707439667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24'},
#  {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 284.554388,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '24'},
#  {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 440.9262895,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '24'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25'},
#  {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25'},
#  {'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 108.877341833,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 68.1487971667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 65.0673291667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 5.1821115,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31'},
#  {'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 138.178952333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '34'},
#  {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '34'},
#  {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '34'},
#  {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '34'},
#  {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '34'},
#  {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '34'},
#  {'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '34'},
#  {'utc_date': datetime.datetime(2018, 3, 4, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '42'},
#  {'utc_date': datetime.datetime(2018, 3, 5, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 21.8589696666,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '42'},
#  {'utc_date': datetime.datetime(2018, 3, 6, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '42'},
#  {'utc_date': datetime.datetime(2018, 3, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 36.5131363333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '42'},
#  {'utc_date': datetime.datetime(2018, 3, 8, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 115.934937,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '42'},
#  {'utc_date': datetime.datetime(2018, 3, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '42'},
#  {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '42'},
#  {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '43'},
#  {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '43'},
#  {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '43'},
#  {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 79.710734,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '43'},
#  {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 9.111304,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '43'},
#  {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '43'},
#  {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '43'},
#  {'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 147.218689666,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '44'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 12.4365233333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '44'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 344.864844333,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '44'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 32.2591195,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '44'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '44'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '44'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '44'},
#  {'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 101.659173,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '45'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 3,
#   'total_minutes_visited': 283.8947265,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '45'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 315.363711333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '45'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '45'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 34.7577358333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '45'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '45'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 235.430412167,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '45'},
#  {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '51'},
#  {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '51'},
#  {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '51'},
#  {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '51'},
#  {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '51'},
#  {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '51'},
#  {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '51'},
#  {'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 3.22752383333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '52'},
#  {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '52'},
#  {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '52'},
#  {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '52'},
#  {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '52'},
#  {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '52'},
#  {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '52'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 25.8814905,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '53'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 17.6570256667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '53'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '53'},
#  {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '53'},
#  {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '53'},
#  {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '53'},
#  {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '53'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 62.3578725,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '57'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 2.67893483333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '57'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 49.1768151667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '57'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 64.5438425,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '57'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 36.440709,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '57'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 199.1518945,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '57'},
#  {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 56.9729128333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '57'},
#  {'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '60'},
#  {'utc_date': datetime.datetime(2018, 1, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '60'},
#  {'utc_date': datetime.datetime(2018, 1, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '60'},
#  {'utc_date': datetime.datetime(2018, 1, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '60'},
#  {'utc_date': datetime.datetime(2018, 1, 18, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '60'},
#  {'utc_date': datetime.datetime(2018, 1, 19, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '60'},
#  {'utc_date': datetime.datetime(2018, 1, 20, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '60'},
#  {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 136.128100167,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '62'},
#  {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '62'},
#  {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 157.255022,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '62'},
#  {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '62'},
#  {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '62'},
#  {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '62'},
#  {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '62'},
#  {'utc_date': datetime.datetime(2017, 12, 6, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 27.2917633333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '64'},
#  {'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 135.03497,
#   'lessons_completed': 3,
#   'projects_completed': 0,
#   'account_key': '64'},
#  {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '64'},
#  {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 109.992393167,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '64'},
#  {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '64'},
#  {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '64'},
#  {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 74.1839003333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '64'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 42.9111793334,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '65'},
#  {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 196.311122667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '65'},
#  {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 3.7023275,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '65'},
#  {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 74.3216586667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '65'},
#  {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 101.079295833,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '65'},
#  {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 3.948076,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '65'},
#  {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '65'},
#  {'utc_date': datetime.datetime(2018, 1, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '67'},
#  {'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 173.549808167,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '67'},
#  {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 312.968414167,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '67'},
#  {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 95.7224171667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '67'},
#  {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 53.0086641667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '67'},
#  {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 177.245182833,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '67'},
#  {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 44.3430183333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '67'},
#  {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '69'},
#  {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '69'},
#  {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '69'},
#  {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '69'},
#  {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '69'},
#  {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '69'},
#  {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '69'},
#  {'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 98.8419471667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '72'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 3,
#   'total_minutes_visited': 277.707878167,
#   'lessons_completed': 3,
#   'projects_completed': 0,
#   'account_key': '72'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 125.0825575,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '72'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 125.8836575,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '72'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 71.0142933333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '72'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 6.02177783333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '72'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '72'},
#  {'utc_date': datetime.datetime(2018, 4, 1, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 32.7516568333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '74'},
#  {'utc_date': datetime.datetime(2018, 4, 2, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '74'},
#  {'utc_date': datetime.datetime(2018, 4, 3, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '74'},
#  {'utc_date': datetime.datetime(2018, 4, 4, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 17.6684443333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '74'},
#  {'utc_date': datetime.datetime(2018, 4, 5, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 40.0605551667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '74'},
#  {'utc_date': datetime.datetime(2018, 4, 6, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '74'},
#  {'utc_date': datetime.datetime(2018, 4, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '74'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 17.658779,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '76'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '76'},
#  {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '76'},
#  {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '76'},
#  {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '76'},
#  {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '76'},
#  {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '76'},
#  {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '78'},
#  {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '78'},
#  {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '78'},
#  {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '78'},
#  {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '78'},
#  {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '78'},
#  {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '78'},
#  {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 4.54286333333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '79'},
#  {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '79'},
#  {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#   'num_courses_visited': 3,
#   'total_minutes_visited': 152.301004333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '79'},
#  {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 259.652116167,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '79'},
#  {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '79'},
#  {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '79'},
#  {'utc_date': datetime.datetime(2017, 12, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '79'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 260.102593666,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '85'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '85'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '85'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '85'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '85'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 47.0882636667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '85'},
#  {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 193.301313334,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '85'},
#  {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '88'},
#  {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '88'},
#  {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '88'},
#  {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '88'},
#  {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '88'},
#  {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 22.7816273333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '88'},
#  {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 83.3821805,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '88'},
#  {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '90'},
#  {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 4.842514,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '90'},
#  {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '90'},
#  {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '90'},
#  {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '90'},
#  {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '90'},
#  {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '90'},
#  {'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '91'},
#  {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 57.8519706666,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '91'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 12.5212006667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '91'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '91'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '91'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '91'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '91'},
#  {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '92'},
#  {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '92'},
#  {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '92'},
#  {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 246.915240167,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '92'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 346.362579333,
#   'lessons_completed': 3,
#   'projects_completed': 0,
#   'account_key': '92'},
#  {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '92'},
#  {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 18.0422446667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '92'},
#  {'utc_date': datetime.datetime(2018, 1, 7, 0, 0),
#   'num_courses_visited': 3,
#   'total_minutes_visited': 442.154309,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '93'},
#  {'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 11.3437871667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '93'},
#  {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 30.32559,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '93'},
#  {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '93'},
#  {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '93'},
#  {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 56.0728645,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '93'},
#  {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 211.327139,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '93'},
#  {'utc_date': datetime.datetime(2018, 2, 5, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 80.8255056667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '97'},
#  {'utc_date': datetime.datetime(2018, 2, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 68.2816868333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '97'},
#  {'utc_date': datetime.datetime(2018, 2, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 87.2653871667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '97'},
#  {'utc_date': datetime.datetime(2018, 2, 8, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 47.5545673334,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '97'},
#  {'utc_date': datetime.datetime(2018, 2, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 77.9725775,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '97'},
#  {'utc_date': datetime.datetime(2018, 2, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 114.270777667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '97'},
#  {'utc_date': datetime.datetime(2018, 2, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 18.6774913333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '97'},
#  {'utc_date': datetime.datetime(2018, 4, 2, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 120.944214833,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '98'},
#  {'utc_date': datetime.datetime(2018, 4, 3, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 128.1958825,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '98'},
#  {'utc_date': datetime.datetime(2018, 4, 4, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 89.841839,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '98'},
#  {'utc_date': datetime.datetime(2018, 4, 5, 0, 0),
#   'num_courses_visited': 1,
# ...
#   'num_courses_visited': 3,
#   'total_minutes_visited': 159.896347833,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '407'},
#  {'utc_date': datetime.datetime(2018, 5, 7, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 329.053285667,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '407'},
#  {'utc_date': datetime.datetime(2018, 5, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '407'},
#  {'utc_date': datetime.datetime(2018, 5, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '407'},
#  {'utc_date': datetime.datetime(2018, 5, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '407'},
#  {'utc_date': datetime.datetime(2018, 5, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '407'},
#  {'utc_date': datetime.datetime(2018, 5, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 11.9631591667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '407'},
#  {'utc_date': datetime.datetime(2018, 4, 1, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 28.1795845,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '408'},
#  {'utc_date': datetime.datetime(2018, 4, 2, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 24.8226406667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '408'},
#  {'utc_date': datetime.datetime(2018, 4, 3, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '408'},
#  {'utc_date': datetime.datetime(2018, 4, 4, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '408'},
#  {'utc_date': datetime.datetime(2018, 4, 5, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '408'},
#  {'utc_date': datetime.datetime(2018, 4, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 6.7703055,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '408'},
#  {'utc_date': datetime.datetime(2018, 4, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '408'},
#  {'utc_date': datetime.datetime(2018, 5, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '410'},
#  {'utc_date': datetime.datetime(2018, 5, 13, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 138.954952667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '410'},
#  {'utc_date': datetime.datetime(2018, 5, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 6.6042025,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '410'},
#  {'utc_date': datetime.datetime(2018, 5, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '410'},
#  {'utc_date': datetime.datetime(2018, 5, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 135.157616333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '410'},
#  {'utc_date': datetime.datetime(2018, 5, 17, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 509.291659833,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '410'},
#  {'utc_date': datetime.datetime(2018, 5, 18, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 161.110283333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '410'},
#  {'utc_date': datetime.datetime(2018, 4, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '411'},
#  {'utc_date': datetime.datetime(2018, 4, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '411'},
#  {'utc_date': datetime.datetime(2018, 4, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '411'},
#  {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '411'},
#  {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '411'},
#  {'utc_date': datetime.datetime(2018, 4, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '411'},
#  {'utc_date': datetime.datetime(2018, 4, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '411'},
#  {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 108.909706333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '412'},
#  {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '412'},
#  {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '412'},
#  {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '412'},
#  {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '412'},
#  {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '412'},
#  {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '412'},
#  {'utc_date': datetime.datetime(2018, 2, 6, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 132.494567,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '413'},
#  {'utc_date': datetime.datetime(2018, 2, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 204.876050333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '413'},
#  {'utc_date': datetime.datetime(2018, 2, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '413'},
#  {'utc_date': datetime.datetime(2018, 2, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '413'},
#  {'utc_date': datetime.datetime(2018, 2, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 35.4039073333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '413'},
#  {'utc_date': datetime.datetime(2018, 2, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 206.1757615,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '413'},
#  {'utc_date': datetime.datetime(2018, 2, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '413'},
#  {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 21.0142001667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '415'},
#  {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 44.3745966667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '415'},
#  {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '415'},
#  {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '415'},
#  {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 117.822271333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '415'},
#  {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '415'},
#  {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '415'},
#  {'utc_date': datetime.datetime(2018, 4, 8, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 133.2434615,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '416'},
#  {'utc_date': datetime.datetime(2018, 4, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 4.29217966667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '416'},
#  {'utc_date': datetime.datetime(2018, 4, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 139.292122667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '416'},
#  {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 24.1589036667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '416'},
#  {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 174.04851,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '416'},
#  {'utc_date': datetime.datetime(2018, 4, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 154.3376065,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '416'},
#  {'utc_date': datetime.datetime(2018, 4, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 93.4693208333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '416'},
#  {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '418'},
#  {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '418'},
#  {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 86.7824926667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '418'},
#  {'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '418'},
#  {'utc_date': datetime.datetime(2018, 1, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '418'},
#  {'utc_date': datetime.datetime(2018, 1, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '418'},
#  {'utc_date': datetime.datetime(2018, 1, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '418'},
#  {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '419'},
#  {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '419'},
#  {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '419'},
#  {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '419'},
#  {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '419'},
#  {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 6.72066133333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '419'},
#  {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '419'},
#  {'utc_date': datetime.datetime(2018, 2, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '423'},
#  {'utc_date': datetime.datetime(2018, 2, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '423'},
#  {'utc_date': datetime.datetime(2018, 2, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '423'},
#  {'utc_date': datetime.datetime(2018, 2, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '423'},
#  {'utc_date': datetime.datetime(2018, 2, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '423'},
#  {'utc_date': datetime.datetime(2018, 2, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '423'},
#  {'utc_date': datetime.datetime(2018, 2, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '423'},
#  {'utc_date': datetime.datetime(2018, 5, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '426'},
#  {'utc_date': datetime.datetime(2018, 5, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '426'},
#  {'utc_date': datetime.datetime(2018, 5, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '426'},
#  {'utc_date': datetime.datetime(2018, 5, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '426'},
#  {'utc_date': datetime.datetime(2018, 5, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '426'},
#  {'utc_date': datetime.datetime(2018, 5, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '426'},
#  ...]

# %%
# How many minutes did each student spend online in their first week
from collections import defaultdict

def group_data(data, key_):
    new_data = defaultdict(list)
    for i in data:
        key = i[key_]
        new_data[key].append(i)
    return new_data

engagements_grouped_by_account = group_data(first_week_engagements, 'account_key')

# %%
engagements_grouped_by_account
# Out:
# defaultdict(list,
#             {'3': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 136.1835995,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3'},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 11.0550435,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3'},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 34.615231,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '3'},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 406.333269167,
#                'lessons_completed': 3,
#                'projects_completed': 0,
#                'account_key': '3'},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 91.475528,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3'},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 148.244103333,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '3'},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3'}],
#              '5': [{'utc_date': datetime.datetime(2018, 1, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 59.7267188333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5'},
#               {'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5'},
#               {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 103.568613833,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5'},
#               {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 80.1818903333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5'},
#               {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 36.2465346667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5'},
#               {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 50.034099,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5'},
#               {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5'}],
#              '15': [{'utc_date': datetime.datetime(2018, 3, 4, 0, 0),
#                'num_courses_visited': 4,
#                'total_minutes_visited': 172.709897334,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '15'},
#               {'utc_date': datetime.datetime(2018, 3, 5, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 108.647330667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15'},
#               {'utc_date': datetime.datetime(2018, 3, 6, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 128.439285667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15'},
#               {'utc_date': datetime.datetime(2018, 3, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15'},
#               {'utc_date': datetime.datetime(2018, 3, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15'},
#               {'utc_date': datetime.datetime(2018, 3, 9, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 186.486383667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15'},
#               {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 387.092143,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15'}],
#              '18': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18'},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 87.1443163333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18'},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 33.370874,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18'},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18'},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18'},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 16.5147731667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18'},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 18.106194,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18'}],
#              '19': [{'utc_date': datetime.datetime(2018, 4, 6, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19'},
#               {'utc_date': datetime.datetime(2018, 4, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19'},
#               {'utc_date': datetime.datetime(2018, 4, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19'},
#               {'utc_date': datetime.datetime(2018, 4, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19'},
#               {'utc_date': datetime.datetime(2018, 4, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19'},
#               {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19'},
#               {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19'}],
#              '24': [{'utc_date': datetime.datetime(2017, 12, 3, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24'},
#               {'utc_date': datetime.datetime(2017, 12, 4, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24'},
#               {'utc_date': datetime.datetime(2017, 12, 5, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24'},
#               {'utc_date': datetime.datetime(2017, 12, 6, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24'},
#               {'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 217.707439667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24'},
#               {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 284.554388,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '24'},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 440.9262895,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '24'}],
#              '25': [{'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25'},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25'},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25'},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25'},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25'},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25'},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25'}],
#              '31': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 108.877341833,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31'},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 68.1487971667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31'},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31'},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 65.0673291667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31'},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31'},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31'},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 5.1821115,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31'}],
#              '34': [{'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 138.178952333,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '34'},
#               {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34'},
#               {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34'},
#               {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34'},
#               {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34'},
#               {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34'},
#               {'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34'}],
#              '42': [{'utc_date': datetime.datetime(2018, 3, 4, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42'},
#               {'utc_date': datetime.datetime(2018, 3, 5, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 21.8589696666,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42'},
#               {'utc_date': datetime.datetime(2018, 3, 6, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42'},
#               {'utc_date': datetime.datetime(2018, 3, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 36.5131363333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42'},
#               {'utc_date': datetime.datetime(2018, 3, 8, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 115.934937,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42'},
#               {'utc_date': datetime.datetime(2018, 3, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42'},
#               {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42'}],
#              '43': [{'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43'},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43'},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43'},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 79.710734,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43'},
#               {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 9.111304,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43'},
#               {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43'},
#               {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43'}],
#              '44': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 147.218689666,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44'},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 12.4365233333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44'},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 344.864844333,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '44'},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 32.2591195,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44'},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44'},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44'},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44'}],
#              '45': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 101.659173,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45'},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 3,
#                'total_minutes_visited': 283.8947265,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '45'},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 315.363711333,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '45'},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45'},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 34.7577358333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45'},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45'},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 235.430412167,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '45'}],
#              '51': [{'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51'},
#               {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51'},
#               {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51'},
#               {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51'},
#               {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51'},
#               {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51'},
#               {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51'}],
#              '52': [{'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 3.22752383333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52'},
#               {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52'},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52'},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52'},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52'},
#               {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52'},
#               {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52'}],
#              '53': [{'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 25.8814905,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53'},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 17.6570256667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53'},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53'},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53'},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53'},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53'},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53'}],
#              '57': [{'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 62.3578725,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57'},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 2.67893483333,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '57'},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 49.1768151667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57'},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 64.5438425,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57'},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 36.440709,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57'},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 199.1518945,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '57'},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 56.9729128333,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '57'}],
#              '60': [{'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60'},
#               {'utc_date': datetime.datetime(2018, 1, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60'},
#               {'utc_date': datetime.datetime(2018, 1, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60'},
#               {'utc_date': datetime.datetime(2018, 1, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60'},
#               {'utc_date': datetime.datetime(2018, 1, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60'},
#               {'utc_date': datetime.datetime(2018, 1, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60'},
#               {'utc_date': datetime.datetime(2018, 1, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60'}],
#              '62': [{'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 136.128100167,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62'},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62'},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 157.255022,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '62'},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62'},
#               {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62'},
#               {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62'},
#               {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62'}],
#              '64': [{'utc_date': datetime.datetime(2017, 12, 6, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 27.2917633333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64'},
#               {'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 135.03497,
#                'lessons_completed': 3,
#                'projects_completed': 0,
#                'account_key': '64'},
#               {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64'},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 109.992393167,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '64'},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64'},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64'},
#               {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 74.1839003333,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '64'}],
#              '65': [{'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 42.9111793334,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '65'},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 196.311122667,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '65'},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 3.7023275,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '65'},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 74.3216586667,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '65'},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 101.079295833,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '65'},
#               {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 3.948076,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '65'},
#               {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '65'}],
#              '67': [{'utc_date': datetime.datetime(2018, 1, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '67'},
#               {'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 173.549808167,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '67'},
#               {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 312.968414167,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '67'},
#               {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 95.7224171667,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '67'},
#               {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 53.0086641667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '67'},
#               {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 177.245182833,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '67'},
#               {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 44.3430183333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '67'}],
#              '69': [{'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '69'},
#               {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '69'},
#               {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '69'},
#               {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '69'},
#               {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '69'},
#               {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '69'},
#               {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '69'}],
#              '72': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 98.8419471667,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '72'},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 3,
#                'total_minutes_visited': 277.707878167,
#                'lessons_completed': 3,
#                'projects_completed': 0,
#                'account_key': '72'},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 125.0825575,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '72'},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 125.8836575,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '72'},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 71.0142933333,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '72'},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 6.02177783333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '72'},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '72'}],
#              '74': [{'utc_date': datetime.datetime(2018, 4, 1, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 32.7516568333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '74'},
#               {'utc_date': datetime.datetime(2018, 4, 2, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '74'},
#               {'utc_date': datetime.datetime(2018, 4, 3, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '74'},
#               {'utc_date': datetime.datetime(2018, 4, 4, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 17.6684443333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '74'},
#               {'utc_date': datetime.datetime(2018, 4, 5, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 40.0605551667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '74'},
#               {'utc_date': datetime.datetime(2018, 4, 6, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '74'},
#               {'utc_date': datetime.datetime(2018, 4, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '74'}],
#              '76': [{'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 17.658779,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '76'},
# ...
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1268'},
#               {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1268'},
#               {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1268'}],
#              '1277': [{'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1277'},
#               {'utc_date': datetime.datetime(2018, 1, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1277'},
#               {'utc_date': datetime.datetime(2018, 1, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1277'},
#               {'utc_date': datetime.datetime(2018, 1, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1277'},
#               {'utc_date': datetime.datetime(2018, 1, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1277'},
#               {'utc_date': datetime.datetime(2018, 1, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1277'},
#               {'utc_date': datetime.datetime(2018, 1, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1277'}],
#              '1285': [{'utc_date': datetime.datetime(2018, 4, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 32.4256981667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285'},
#               {'utc_date': datetime.datetime(2018, 4, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285'},
#               {'utc_date': datetime.datetime(2018, 4, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285'},
#               {'utc_date': datetime.datetime(2018, 4, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285'},
#               {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285'},
#               {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285'},
#               {'utc_date': datetime.datetime(2018, 4, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285'}],
#              '1287': [{'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287'},
#               {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287'},
#               {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287'},
#               {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287'},
#               {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287'},
#               {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287'},
#               {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287'}],
#              '1289': [{'utc_date': datetime.datetime(2017, 12, 4, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 5.45628333333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289'},
#               {'utc_date': datetime.datetime(2017, 12, 5, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289'},
#               {'utc_date': datetime.datetime(2017, 12, 6, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289'},
#               {'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289'},
#               {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289'},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289'},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289'}],
#              '1292': [{'utc_date': datetime.datetime(2018, 1, 7, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 22.1842831666,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292'},
#               {'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292'},
#               {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 3.01193883333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292'},
#               {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 35.984489,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292'},
#               {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 129.557927667,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292'},
#               {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 35.8307223333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292'},
#               {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 6.63614233333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292'}],
#              '1299': [{'utc_date': datetime.datetime(2018, 2, 5, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299'},
#               {'utc_date': datetime.datetime(2018, 2, 6, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 113.791118833,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299'},
#               {'utc_date': datetime.datetime(2018, 2, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299'},
#               {'utc_date': datetime.datetime(2018, 2, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299'},
#               {'utc_date': datetime.datetime(2018, 2, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299'},
#               {'utc_date': datetime.datetime(2018, 2, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299'},
#               {'utc_date': datetime.datetime(2018, 2, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299'}],
#              '1303': [{'utc_date': datetime.datetime(2018, 4, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303'},
#               {'utc_date': datetime.datetime(2018, 4, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303'},
#               {'utc_date': datetime.datetime(2018, 4, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303'},
#               {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303'},
#               {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303'},
#               {'utc_date': datetime.datetime(2018, 4, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303'},
#               {'utc_date': datetime.datetime(2018, 4, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303'}],
#              '1305': [{'utc_date': datetime.datetime(2018, 5, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 2.05622333333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305'},
#               {'utc_date': datetime.datetime(2018, 5, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305'},
#               {'utc_date': datetime.datetime(2018, 5, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 7.7152505,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305'},
#               {'utc_date': datetime.datetime(2018, 5, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305'},
#               {'utc_date': datetime.datetime(2018, 5, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305'},
#               {'utc_date': datetime.datetime(2018, 5, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305'},
#               {'utc_date': datetime.datetime(2018, 5, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305'}]})

# %%
for k,v in engagements_grouped_by_account.items():
    print(k)
    print("="*50)
    print(v)
    break
# Out:
# 3
# ==================================================
# [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0), 'num_courses_visited': 2, 'total_minutes_visited': 136.1835995, 'lessons_completed': 0, 'projects_completed': 0, 'account_key': '3'}, {'utc_date': datetime.datetime(2017, 11, 11, 0, 0), 'num_courses_visited': 1, 'total_minutes_visited': 11.0550435, 'lessons_completed': 0, 'projects_completed': 0, 'account_key': '3'}, {'utc_date': datetime.datetime(2017, 11, 12, 0, 0), 'num_courses_visited': 1, 'total_minutes_visited': 34.615231, 'lessons_completed': 1, 'projects_completed': 0, 'account_key': '3'}, {'utc_date': datetime.datetime(2017, 11, 13, 0, 0), 'num_courses_visited': 1, 'total_minutes_visited': 406.333269167, 'lessons_completed': 3, 'projects_completed': 0, 'account_key': '3'}, {'utc_date': datetime.datetime(2017, 11, 14, 0, 0), 'num_courses_visited': 2, 'total_minutes_visited': 91.475528, 'lessons_completed': 0, 'projects_completed': 0, 'account_key': '3'}, {'utc_date': datetime.datetime(2017, 11, 15, 0, 0), 'num_courses_visited': 1, 'total_minutes_visited': 148.244103333, 'lessons_completed': 2, 'projects_completed': 0, 'account_key': '3'}, {'utc_date': datetime.datetime(2017, 11, 16, 0, 0), 'num_courses_visited': 0, 'total_minutes_visited': 0.0, 'lessons_completed': 0, 'projects_completed': 0, 'account_key': '3'}]

# %%
def sum_records(data, field):
    new_data = {}
    for k,v in data.items():
        sum_ = 0
        for i in v:
            sum_ += i[field]
        new_data[k] = sum_
    return new_data

minutes_per_account = sum_records(engagements_grouped_by_account, 'total_minutes_visited')
minutes_per_account
# Out:
# {'3': 827.9067745000001,
#  '5': 329.7578566663,
#  '15': 983.375040335,
#  '18': 155.1361575,
#  '19': 0.0,
#  '24': 943.188117167,
#  '25': 0.0,
#  '31': 247.2755796664,
#  '34': 138.178952333,
#  '42': 174.3070429999,
#  '43': 88.822038,
#  '44': 536.7791768323,
#  '45': 971.1057588333,
#  '51': 0.0,
#  '52': 3.22752383333,
#  '53': 43.538516166700006,
#  '57': 471.32298133332995,
#  '60': 0.0,
#  '62': 293.383122167,
#  '64': 346.5030268336,
#  '65': 422.27366000010005,
#  '67': 856.8375048337,
#  '69': 0.0,
#  '72': 704.5521115003299,
#  '74': 90.48065633329999,
#  '76': 17.658779,
#  '78': 0.0,
#  '79': 416.49598383333,
#  '85': 500.4921706667001,
#  '88': 106.16380783330001,
#  '90': 4.842514,
#  '91': 70.37317133330001,
#  '92': 611.3200641666999,
#  '93': 751.2236896667,
#  '97': 494.84799350040004,
#  '98': 525.6444536663,
#  '99': 317.10422516660003,
#  '101': 148.7306783333,
#  '105': 312.1800340007,
#  '106': 211.82116566633,
#  '108': 164.27089083347,
#  '110': 1214.55291799937,
#  '111': 169.159592167,
#  '113': 83.7769855,
#  '119': 103.9043659999,
#  '123': 0.0,
#  '130': 0.0,
#  '132': 1196.803629999,
#  '134': 1017.1034851664001,
#  '136': 13.8563716667,
#  '138': 46.4254303333,
#  '140': 174.0351705003,
#  '141': 544.992658666,
#  '142': 505.63867666629994,
#  '143': 405.0228675003,
#  '147': 416.4968900006,
#  '148': 0.0,
#  '150': 414.14088366667,
#  '151': 908.4660900005999,
#  '153': 116.8988095,
#  '157': 8.3032715,
#  '159': 18.4407191667,
#  '160': 630.1675615003,
#  '161': 531.8882431671,
#  '165': 962.5736773336,
#  '168': 1138.3847963327,
#  '169': 92.5594045,
#  '170': 586.7042849994001,
#  '171': 1887.391213833,
#  '174': 414.12743866659997,
#  '178': 783.3383063341,
#  '179': 913.6758890002999,
#  '180': 195.8380553337,
#  '181': 166.14326016626998,
#  '185': 0.0,
#  '187': 629.3766914993301,
#  '190': 353.05917583350003,
#  '191': 28.86811600007,
#  '193': 0.0,
#  '197': 931.3076661670001,
#  '203': 605.7708455,
#  '208': 356.77551816640005,
#  '217': 613.8106874997,
#  '220': 346.78228750000005,
#  '221': 178.70479883369998,
#  '227': 548.4951726663,
#  '229': 131.7264965,
#  '243': 46.605140666699995,
#  '251': 357.82092916600004,
#  '253': 453.2741088337,
#  '256': 0.0,
#  '258': 595.2719906673,
#  '259': 736.3565788330001,
#  '261': 0.0,
#  '263': 34.2810203333,
#  '264': 110.09569266679999,
#  '265': 371.26458716729996,
#  '268': 314.3331800003,
#  '270': 1020.3306876671,
#  '272': 1203.2224428333002,
#  '279': 375.0586186666,
#  '284': 283.2611105,
#  '285': 183.17598216667002,
#  '289': 955.78319766497,
#  '293': 497.8218254996,
#  '306': 6.61027,
#  '312': 62.0910973333,
#  '315': 657.0126268326,
#  '316': 1735.943607166,
#  '321': 6.39519683333,
#  '322': 0.0,
#  '323': 397.24734133329997,
#  '329': 36.151552,
#  '334': 9.55376083333,
#  '335': 855.4038108340001,
#  '338': 0.0,
#  '339': 0.0,
#  '343': 83.295313,
#  '347': 104.97653,
#  '348': 445.67912983302995,
#  '361': 1053.7764165013,
#  '362': 58.3151085,
#  '366': 23.55166316667,
#  '367': 220.21062866679998,
#  '378': 0.0,
#  '386': 0.0,
#  '388': 8.4371975,
#  '394': 808.5665558337,
#  '397': 261.9154958334,
#  '402': 81.87143850003,
#  '404': 611.4195701674,
#  '407': 500.9127926667,
#  '408': 59.7725306667,
#  '410': 951.118714666,
#  '411': 0.0,
#  '412': 108.909706333,
#  '413': 578.9502861663,
#  '415': 183.2110681664,
#  '416': 722.84210483367,
#  '418': 86.7824926667,
#  '419': 6.72066133333,
#  '423': 0.0,
#  '426': 0.0,
#  '427': 413.5420181666,
#  '429': 0.0,
#  '431': 77.9742268333,
#  '434': 696.5725646662999,
#  '439': 278.8646333337,
#  '440': 45.9874008334,
#  '441': 1065.2951291673999,
#  '442': 383.48329066596,
#  '444': 0.0,
#  '447': 119.916663667,
#  '448': 28.87681983337,
#  '458': 121.39381849997,
#  '460': 1275.8162838333,
#  '465': 53.1803671667,
#  '467': 207.27739616670002,
#  '473': 0.0,
#  '474': 285.75573750030003,
#  '477': 779.5860966676,
#  '480': 0.0,
#  '483': 716.3825241659999,
#  '499': 367.3854126667,
#  '500': 89.3707275,
#  '504': 388.7726185,
#  '505': 459.3740381662999,
#  '507': 63.843047333330006,
#  '512': 4.26499566667,
#  '514': 62.84829066659999,
#  '520': 109.5149769999,
#  '521': 406.0453698336,
#  '523': 0.0,
#  '524': 85.2622293333,
#  '525': 0.0,
#  '528': 514.0743979996,
#  '529': 315.94653349997,
#  '532': 422.6295078334,
#  '534': 609.6590520007001,
#  '541': 20.879544833329998,
#  '544': 1421.7436063333,
#  '547': 0.0,
#  '549': 32.0522478333,
#  '550': 18.9512853333,
#  '557': 0.0,
#  '558': 1105.2969810004001,
#  '563': 21.972605,
#  '564': 581.0392821667,
#  '569': 1477.0239483322998,
#  '571': 312.2213373334,
#  '576': 911.11994133237,
#  '577': 120.55847799993,
#  '580': 712.1588875006701,
#  '583': 762.169280667,
#  '584': 0.0,
#  '587': 175.2765656667,
#  '589': 168.39389983367,
#  '590': 52.2673098334,
#  '591': 0.0,
#  '597': 1047.649452501,
#  '599': 0.0,
#  '601': 267.87404783297,
#  '602': 615.9597956661,
#  '606': 456.3332818333,
#  '610': 653.1940411656001,
#  '611': 382.93037050067,
#  '612': 52.9136506667,
#  '618': 513.8126981664001,
#  '622': 396.82058733329995,
#  '623': 230.70437450010002,
#  '624': 1026.8480728333,
#  '626': 95.1225038333,
#  '630': 394.5387589999,
#  '631': 237.7646521667,
#  '634': 223.73943383300002,
#  '636': 169.3917738333,
#  '637': 89.0572956666,
#  '639': 416.14186616669997,
#  '640': 0.0,
#  '641': 340.70627749999994,
#  '643': 14.4853385,
#  '645': 847.3979861667,
#  '649': 700.4743598327,
#  '650': 114.84451633329999,
#  '651': 1346.7158483327,
#  '655': 177.8367486667,
#  '657': 0.0,
#  '660': 193.848226,
#  '661': 92.5547231666,
#  '666': 138.052647,
#  '667': 144.1243173333,
#  '669': 0.0,
#  '670': 454.273163499,
#  '671': 115.15559099992998,
#  '678': 100.0702155,
#  '682': 25.243540000000003,
#  '690': 159.93331549997,
#  '692': 16.604203,
#  '693': 0.0,
#  '696': 666.3290910003,
#  '697': 88.1119545,
#  '698': 56.45108966666999,
#  '702': 0.0,
#  '704': 0.0,
#  '705': 0.0,
#  '706': 1329.9598305,
#  '709': 88.0103965,
#  '710': 3.56199133333,
#  '712': 253.23675750029997,
#  '713': 139.060529,
#  '718': 0.0,
#  '719': 9.4907925,
#  '720': 401.81893949967,
#  '722': 29.9067615,
#  '726': 21.1284496667,
#  '729': 0.0,
#  '730': 41.7199715,
#  '732': 219.926066667,
#  '735': 0.0,
#  '736': 313.50181033333,
#  '743': 0.0,
#  '744': 374.5761038331,
#  '746': 706.5435295006,
#  '752': 30.5951761667,
#  '753': 116.628876833,
#  '756': 0.0,
#  '757': 354.6223496663,
#  '759': 0.0,
#  '761': 100.06368333333,
#  '762': 85.29257,
#  '769': 135.6825435,
#  '776': 0.0,
#  '777': 199.31994916669998,
#  '778': 48.1974151667,
#  '779': 4.2604045,
#  '780': 0.0,
#  '785': 4.78649716667,
#  '786': 23.695871500029998,
#  '787': 0.0,
#  '792': 1369.641421833,
#  '793': 0.0,
#  '796': 0.0,
#  '800': 122.87407133333,
#  '801': 0.0,
#  '804': 22.7346656667,
#  '808': 106.2993215,
#  '811': 1138.3177014993998,
#  '822': 27.9431673333,
#  '823': 0.0,
#  '824': 260.47024649996,
#  '825': 27.3957285,
#  '828': 345.17664533360005,
#  '829': 129.762569,
#  '831': 51.016355999999995,
#  '833': 2.38093233333,
#  '835': 0.0,
#  '836': 0.0,
#  '839': 13.587055,
#  '844': 817.60166266567,
#  '846': 32.6861011667,
#  '855': 92.6896001666,
#  '856': 0.0,
#  '857': 0.0,
#  '858': 260.94864483347,
#  '859': 2.54122166667,
#  '864': 53.1295885,
#  '866': 0.0,
#  '867': 0.0,
#  '868': 13.442560666670001,
#  '873': 30.2541315,
#  '877': 26.5230981667,
#  '882': 0.0,
#  '896': 0.0,
#  '897': 22.0889656667,
#  '900': 0.0,
#  '905': 108.9832133333,
#  '906': 0.0,
#  '909': 63.3749175,
#  '912': 0.0,
#  '913': 72.9583085,
#  '916': 65.7383995,
#  '918': 21.086721,
#  '919': 663.5424139989,
#  '923': 0.0,
#  '927': 125.44656916667,
#  '932': 0.0,
#  '934': 5.03956,
#  '937': 160.1049253333,
#  '938': 69.45209899999999,
#  '941': 2.99934966667,
#  '948': 94.3237553333,
#  '952': 120.657056167,
#  '954': 91.64868466669999,
#  '955': 240.5959745003,
#  '956': 6.80688283333,
#  '958': 0.0,
#  '965': 666.393701501,
#  '966': 26.58431933333,
#  '969': 24.9669023333,
#  '972': 96.1137128333,
#  '976': 65.0527071667,
#  '983': 0.0,
#  '984': 188.30785633327,
#  '985': 46.494977,
#  '988': 61.420162,
#  '989': 0.0,
#  '1007': 0.0,
#  '1009': 0.0,
#  '1011': 118.71332966671,
#  '1013': 4.3800225,
#  '1015': 38.87817050003,
#  '1019': 75.87298200000001,
#  '1022': 23.54994816667,
#  '1029': 3.50885666667,
#  '1030': 218.55650866673005,
#  '1033': 959.9534376661,
#  '1038': 0.0,
#  '1040': 12.9824898333,
#  '1042': 45.5670335,
#  '1049': 37.853095,
#  '1052': 117.195806333,
#  '1053': 81.4415533333,
#  '1054': 0.0,
#  '1055': 71.5736406667,
#  '1058': 0.0,
#  '1060': 1768.5227493319999,
#  '1062': 366.3194163334,
#  '1066': 0.0,
#  '1071': 0.0,
#  '1074': 0.0,
#  '1075': 90.6038805,
#  '1077': 152.213267167,
#  '1082': 51.1061375,
#  '1088': 0.0,
#  '1089': 53.190095,
#  '1090': 0.0,
#  '1094': 464.4721495011001,
#  '1095': 30.0975526667,
#  '1099': 108.8893720001,
#  '1102': 0.0,
#  '1103': 0.0,
#  '1107': 73.6289658334,
#  '1111': 0.0,
#  '1115': 0.0,
#  '1117': 0.0,
#  '1118': 89.38367816659999,
#  '1121': 20.21580533333,
#  '1123': 12.6563396667,
#  '1124': 0.0,
#  '1128': 53.4711175,
#  '1130': 137.6759001667,
#  '1139': 321.75119083367,
#  '1140': 129.85920366667,
#  '1142': 0.0,
#  '1146': 105.57724800007,
#  '1153': 565.6616593333,
#  '1160': 2.70408483333,
#  '1161': 87.8123571667,
#  '1163': 56.4237046666,
#  '1167': 870.43417899963,
#  '1170': 0.0,
#  '1174': 76.1418825,
#  '1175': 2.7094835,
#  '1178': 0.0,
#  '1183': 258.849289167,
#  '1188': 200.75333083330003,
#  '1189': 292.8858635,
#  '1194': 168.1376205,
#  '1198': 6.5907805,
#  '1199': 4.71476416667,
#  '1200': 696.57720983267,
#  '1201': 395.022838667,
#  '1202': 48.67926333336,
#  '1204': 291.7782771666,
#  '1205': 0.0,
#  '1207': 26.4703245,
#  '1208': 114.066953,
#  '1210': 430.7856678337,
#  '1211': 3.56441583333,
#  '1212': 0.0,
#  '1214': 12.822523,
#  '1215': 1360.7287001670002,
#  '1217': 32.0539045,
#  '1220': 118.30495933329999,
#  '1226': 0.0,
#  '1236': 0.0,
#  '1242': 49.1640855,
#  '1243': 62.9114363333,
#  '1244': 53.5962256666,
#  '1247': 79.19556549999999,
#  '1248': 3.50918183333,
#  '1249': 9.62371516667,
#  '1253': 0.0,
#  '1254': 187.32349033330001,
#  '1259': 94.2427361666,
#  '1260': 0.0,
#  '1264': 2.01734133333,
#  '1266': 0.0,
#  '1268': 11.3308886667,
#  '1277': 0.0,
#  '1285': 32.4256981667,
#  '1287': 0.0,
#  '1289': 5.45628333333,
#  '1292': 233.20550333356,
#  '1299': 113.791118833,
#  '1303': 0.0,
#  '1305': 9.771473833329999}

# %% [markdown]
# ### 4. Finalizing/Summarizing Data
